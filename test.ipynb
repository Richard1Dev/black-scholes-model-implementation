# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis = np.linspace(-5, 5, 101)
y_axis = x_axis**2

plt.figure(figsize=(8,5))
plt.plot(x_axis, y_axis, label="Test plot", linewidth=2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("test")
plt.legend()
plt.grid(True)
